# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel(r"D:\Data Science Projects\NLP Projects\Review Intelligence System (NLP+BERT)\data\zoom_classification_dataset_final.xlsx")

# %%
df
# Out:
#                                            User Review Positive/Negative  \
# 0    Breakout room settings are buried and hard to ...          Negative
# 1      No lag during a 2-hour session — very reliable.          Positive
# 2            Difficult to manage participants as host.          Negative
# 3     Screen froze multiple times during screen share.          Negative
# 4          Zoom becomes unresponsive after 10 minutes.          Negative
# ..                                                 ...               ...
# 163                       App loads slowly every time.          Negative
# 164  Mic access denied even though permissions were...          Negative
# 165        Random crashes when switching audio device.          Negative
# 166  Couldn't hear anything after joining. Had to r...          Negative
# 167  Audio was distorted and robotic throughout the...          Negative
#
#                     Negative Category
# 0    User Interface / Usability Issue
# ...

# %%
df['Negative Category']
# Out:
# 0      User Interface / Usability Issue
# 1                                   NaN
# 2      User Interface / Usability Issue
# 3                Performance / Slowness
# 4                   App Stability Issue
#                      ...
# 163              Performance / Slowness
# 164                 Audio / Voice Issue
# 165                 App Stability Issue
# 166                 Audio / Voice Issue
# 167                 Audio / Voice Issue
# Name: Negative Category, Length: 168, dtype: object

# %%
df['Negative Category'].value_counts()
# Out:
# Negative Category
# App Stability Issue                 20
# Audio / Voice Issue                 20
# User Interface / Usability Issue    19
# Performance / Slowness              19
# Screen Sharing Issue                19
# Connection or Access Issue          19
# Video Quality Issue                 16
# Recording / Playback Issue           6
# Name: count, dtype: int64

# %%
sns.countplot(df['Negative Category'])
# Out:
# C:\Users\rahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:1273: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(aggregator, agg_var)
# <Axes: xlabel='count', ylabel='Negative Category'>
